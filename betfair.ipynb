# %%
## BetFair - going to read the main page and grab all the Football game odds. 

import requests
from bs4 import BeautifulSoup as bs
from IPython.core.display import display, HTML    # this is so we can display HTML in Jupyter
import re

s = requests.Session()
soup = bs(s.get('https://www.betfair.com/sport/inplay').content, 'html.parser')


LIs = soup.findAll('li', class_ = ['com-coupon-line'])


def report_game(data):
    p0 = re.compile('data-sport="(.+?)"')
    sport = p0.search(data).group(1)
    print(f'{sport} :',end = '')
    if sport != 'SOCCER': return
    p1 = re.compile('data-competition="(.+?)"')
    competition = p1.search(data).group(1)
    p2 = re.compile('data-event="(.+?)"')
    event = p2.search(data).group(1)
    p3 = re.compile('sel-0.+?display-fraction-price">(.+?)</span>.+?sel-1.+?display-fraction-price">(.+?)</span>.+?sel-2.+?display-fraction-price">(.+?)</span>.+?')
    #print(p3.search(data).group(1,2,3))
    hw, draw, aw = p3.search(data).group(1,2,3)
    p4 = re.compile('<span class="home-team-name" title="(.+?)".+?<span class="away-team-name" title="(.+?)"')
    home, away = p4.search(data).group(1,2)

    print(f'  Competition : {competition} \nevent                         : {event}')
    print(f'{home:20} Home-Win : {hw}')
    print(f'{"draw":20} Draw     : {draw}')
    print(f'{away:20} Away-Win : {aw}')

i = 0
for li in LIs:
    print(f'\n {i:3} : -', end='')
    report_game(str(li).replace('\n',''))
    i += 1
# Out:
#    0 : -SOCCER :  Competition : English FA Cup
# event                         : Fulham v Burnley
# Fulham               Home-Win : 7/1
# draw                 Draw     : 14/5
# Burnley              Away-Win : 40/85
#
#    1 : -SOCCER :  Competition : English FA Cup
# event                         : Brentford v Leicester
# Brentford            Home-Win : 11/10
# draw                 Draw     : 2/1
# Leicester            Away-Win : 14/5
#
#    2 : -SOCCER :  Competition : English Championship
# event                         : Middlesbrough v Blackburn
# Middlesbrough        Home-Win : 13/8
# draw                 Draw     : 31/20
# Blackburn            Away-Win : 23/10
#
#    3 : -SOCCER :  Competition : Spanish La Liga
# event                         : Elche v Barcelona
# Elche                Home-Win : 17/2
# draw                 Draw     : 15/4
# Barcelona            Away-Win : 1/3
#
#    4 : -SOCCER :  Competition : Italian Serie A
# event                         : Genoa v Cagliari
# Genoa                Home-Win : 2/7
# draw                 Draw     : 16/5
# Cagliari             Away-Win : 19/1
#
#    5 : -SOCCER :  Competition : Italian Serie A
# event                         : Verona v Napoli
# Verona               Home-Win : 1/2
# draw                 Draw     : 23/10
# Napoli               Away-Win : 10/1
#
#    6 : -SOCCER :  Competition : French Ligue 1
# event                         : Reims v Brest
# Reims                Home-Win : 1/4
# draw                 Draw     : 17/5
# Brest                Away-Win : 25/1
#
#    7 : -SOCCER :  Competition : French Ligue 1
# event                         : Metz v Nantes
# Metz                 Home-Win : 2/9
# draw                 Draw     : 15/4
# Nantes               Away-Win : 22/1
#
#    8 : -SOCCER :  Competition : French Ligue 1
# event                         : Dijon v Strasbourg
# Dijon                Home-Win : 6/1
# draw                 Draw     : 8/15
# Strasbourg           Away-Win : 11/4
#
#    9 : -SOCCER :  Competition : German Bundesliga
# event                         : Schalke 04 v Bayern Munich
# Schalke 04           Home-Win : 40/1
# draw                 Draw     : 11/1
# Bayern Munich        Away-Win : 1/16
#
#   10 : -SOCCER :  Competition : Spanish Segunda Division
# event                         : UD Logrones v Oviedo
# UD Logrones          Home-Win : 11/4
# draw                 Draw     : 7/5
# Oviedo               Away-Win : 7/5
#
#   11 : -SOCCER :  Competition : Italian Serie B
# event                         : Lecce v Empoli
# Lecce                Home-Win : 150/1
# draw                 Draw     : 19/1
# Empoli               Away-Win : 1/40
#
#   12 : -SOCCER :  Competition : Belgian First Division A
# event                         : Zulte-Waregem v KFCO Beerschot Wilrijk
# Zulte-Waregem        Home-Win : 9/5
# draw                 Draw     : 9/5
# Kfco Beerschot Wilrijk Away-Win : 9/5
#
#   13 : -SOCCER :  Competition : Swiss Super League
# event                         : FC Vaduz v Young Boys
# FC Vaduz             Home-Win : 7/1
# draw                 Draw     : 14/5
# Young Boys           Away-Win : 4/9
#
#   14 : -SOCCER :  Competition : Swiss Super League
# event                         : St Gallen v Lugano
# St Gallen            Home-Win : 7/5
# draw                 Draw     : 17/10
# Lugano               Away-Win : 12/5
#
#   15 : -SOCCER :  Competition : Czech 1 Liga
# event                         : Plzen v Pardubice
# Plzen                Home-Win : 1/33
# draw                 Draw     : 14/1
# Pardubice            Away-Win : 80/1
#
#   16 : -SOCCER :  Competition : Greek Super League
# event                         : Panaitolikos v Lamia
# Panaitolikos         Home-Win : 17/10
# draw                 Draw     : 7/5
# Lamia                Away-Win : 12/5
#
#   17 : -SOCCER :  Competition : Greek Super League
# event                         : Pas Giannina v NFC Volos
# PAS Giannina         Home-Win : 13/5
# draw                 Draw     : 23/10
# NFC Volos            Away-Win : EVS
#
#   18 : -SOCCER :  Competition : Italian Serie C
# event                         : Fano v Perugia
# Fano                 Home-Win : 13/2
# draw                 Draw     : 4/11
# Perugia              Away-Win : 31/10
#
#   19 : -SOCCER :  Competition : Italian Serie C
# event                         : Vibonese v Cavese
# Vibonese             Home-Win : 16/5
# draw                 Draw     : 2/5
# Cavese               Away-Win : 11/2
#
#   20 : -SOCCER :  Competition : Italian Serie C
# event                         : Pergolettese v Lucchese
# Pergolettese         Home-Win : 16/1
# draw                 Draw     : 29/10
# Lucchese             Away-Win : 1/4
#
#   21 : -SOCCER :  Competition : Italian Serie C
# event                         : Giana Erminio v Lecco
# Giana Erminio        Home-Win : 4/1
# draw                 Draw     : 2/5
# Lecco                Away-Win : 4/1
#
#   22 : -SOCCER :  Competition : Italian Serie C
# event                         : Grosseto v Piacenza
# Grosseto             Home-Win :
# draw                 Draw     : 70/1
# Piacenza             Away-Win : 450/1
#
#   23 : -SOCCER :  Competition : Italian Serie C
# event                         : Mantova v Fermana
# Mantova              Home-Win : 1/14
# draw                 Draw     : 13/2
# Fermana              Away-Win : 75/1
#
#   24 : -SOCCER :  Competition : Italian Serie C
# event                         : Sambenedettese v Carpi
# Sambenedettese       Home-Win :
# draw                 Draw     : 500/1
# Carpi                Away-Win : 450/1
#
#   25 : -SOCCER :  Competition : Italian Serie C
# event                         : Viterbese v Ternana
# Viterbese            Home-Win : 30/1
# draw                 Draw     : 9/2
# Ternana              Away-Win : 1/7
#
#   26 : -SOCCER :  Competition : Italian Serie C
# event                         : Alessandria v Pistoiese
# Alessandria          Home-Win : 1/10
# draw                 Draw     : 11/2
# Pistoiese            Away-Win : 45/1
#
#   27 : -SOCCER :  Competition : Italian Serie C
# event                         : SSD Bari v US Virtus Francavilla Calcio
# SSD Bari             Home-Win :
# draw                 Draw     : 375/1
# US Virtus Francavilla Calcio Away-Win : 450/1
#
#   28 : -SOCCER :  Competition : Italian Serie C
# event                         : Matelica v Triestina
# Matelica             Home-Win : 1/40
# draw                 Draw     : 15/1
# Triestina            Away-Win : 100/1
#
#   29 : -SOCCER :  Competition : Italian Serie C
# event                         : Sudtirol v Ravenna
# Sudtirol             Home-Win : 1/14
# draw                 Draw     : 13/2
# Ravenna              Away-Win : 66/1
#
#   30 : -SOCCER :  Competition : Portuguese Primeira Liga
# event                         : Maritimo v Pacos Ferreira
# Maritimo             Home-Win : 9/5
# draw                 Draw     : 7/5
# Pacos Ferreira       Away-Win : 23/10
#
#   31 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : CF Calamocha v CF Epila
# CF Calamocha         Home-Win : 17/10
# draw                 Draw     : 5/4
# CF Epila             Away-Win : 13/5
#
#   32 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : Pena Sport v Murchante FC
# Pena Sport           Home-Win : 5/6
# draw                 Draw     : 19/10
# Murchante FC         Away-Win : 15/4
#
#   33 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : CD Cayon v Ribamontan Al Mar CF
# CD Cayon             Home-Win : 1/20
# draw                 Draw     : 10/1
# Ribamontan Al Mar CF Away-Win : 35/1
#
#   34 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : UD Santa Marta v Jupiter Leones
# UD Santa Marta       Home-Win : 6/1
# draw                 Draw     : 11/4
# Jupiter Leones       Away-Win : 40/85
#
#   35 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : CD Vitoria v Pasaia Kirol Elkartea
# CD Vitoria           Home-Win : 13/10
# draw                 Draw     : 5/4
# Pasaia Kirol Elkartea Away-Win : 7/2
#
#   36 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : CD Burgos Promesas v Real Avila CF
# CD Burgos Promesas   Home-Win : 12/5
# draw                 Draw     : 13/10
# Real Avila CF        Away-Win : 13/8
#
#   37 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : Alcala RSD v DAV Santa Ana
# Alcala RSD           Home-Win : 17/20
# draw                 Draw     : 15/8
# DAV Santa Ana        Away-Win : 4/1
#
#   38 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : CD Tuilla v Real Titanico
# CD Tuilla            Home-Win : 8/13
# draw                 Draw     : 11/5
# Real Titanico        Away-Win : 5/1
#
#   39 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : UD Fraga v CD Valdefierro
# UD Fraga             Home-Win : 4/6
# draw                 Draw     : 5/2
# CD Valdefierro       Away-Win : 4/1
#
#   40 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : UE Valls v UE Castelldefels
# UE Valls             Home-Win : 11/5
# draw                 Draw     : 2/1
# UE Castelldefels     Away-Win : 11/10
#
#   41 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : CD Bullense v Estrella Grana El Palmar
# CD Bullense          Home-Win : 6/5
# draw                 Draw     : 2/1
# Estrella Grana El Palmar Away-Win : 9/4
#
#   42 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : AD Lobon v Emd Aceuchal
# AD Lobon             Home-Win : 17/10
# draw                 Draw     : 2/1
# EMD Aceuchal         Away-Win : 6/4
#
#   43 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : CP Valdivia v CD Coria
# CP Valdivia          Home-Win : 22/1
# draw                 Draw     : 8/1
# CD Coria             Away-Win : 1/14
#
#   44 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : Utebo CF v CD Cuarte
# Utebo CF             Home-Win : 23/20
# draw                 Draw     : 2/1
# CD Cuarte            Away-Win : 12/5
#
#   45 : -SOCCER :  Competition : Italian Serie D
# event                         : Desenzano Calvina v Seregno Calcio
# Desenzano Calvina    Home-Win : 100/1
# draw                 Draw     :
# Seregno Calcio       Away-Win : 175/1
#
#   46 : -SOCCER :  Competition : Italian Serie D
# event                         : ASD SS Nola 1925 v FC Giugliano
# ASD SS Nola 1925     Home-Win :
# draw                 Draw     : 450/1
# FC Giugliano         Away-Win : 450/1
#
#   47 : -SOCCER :  Competition : Italian Serie D
# event                         : ASD Imperia v GS Arconatese
# ASD Imperia          Home-Win : 1/7
# draw                 Draw     : 4/1
# GS Arconatese        Away-Win : 33/1
#
#   48 : -SOCCER :  Competition : Hungarian NB I
# event                         : Paks v Diosgyori
# Paks                 Home-Win : 1/25
# draw                 Draw     : 11/1
# Diosgyori            Away-Win : 40/1
#
#   49 : -SOCCER :  Competition : Cypriot 1st Division
# event                         : APOEL v Anorthosis
# APOEL                Home-Win : 4/1
# draw                 Draw     : 4/11
# Anorthosis           Away-Win : 9/2
#
#   50 : -SOCCER :  Competition : English Women's Matches
# event                         : London City Lionesses v Blackburn Rovers (W)
# London City Lionesses Home-Win :
# draw                 Draw     : 80/1
# Blackburn Rovers (W) Away-Win : 500/1
#
#   51 : -SOCCER :  Competition : Portuguese Segunda Liga
# event                         : Chaves v Arouca
# Chaves               Home-Win : 1/5
# draw                 Draw     : 18/5
# Arouca               Away-Win : 22/1
#
#   52 : -SOCCER :  Competition : Maltese 1st Division
# event                         : Zebbug Rangers FC v Fgura United
# Zebbug Rangers FC    Home-Win :
# draw                 Draw     : 150/1
# Fgura United         Away-Win : 500/1
#
#   53 : -SOCCER :  Competition : Belgian First Division B
# event                         : Westerlo v Seraing Utd
# Westerlo             Home-Win : 31/20
# draw                 Draw     : 8/5
# Seraing Utd          Away-Win : 21/10
#
#   54 : -SOCCER :  Competition : Saudi Professional League
# event                         : Al-Fateh (KSA) v Al-Raed (KSA)
# Al-Fateh (KSA)       Home-Win : 5/1
# draw                 Draw     : 5/2
# Al-Raed (KSA)        Away-Win : 8/13
#
#   55 : -SOCCER :  Competition : Chilean Primera B
# event                         : Puerto Montt v Deportes Melipilla
# Puerto Montt         Home-Win : 450/1
# draw                 Draw     : 30/1
# Deportes Melipilla   Away-Win : 1/200
#
#   56 : -SOCCER :  Competition : Indian Super League
# event                         : Bengaluru FC v Odisha
# Bengaluru FC         Home-Win : 14/1
# draw                 Draw     : 5/2
# Odisha               Away-Win : 4/11
#
#   57 : -SOCCER :  Competition : Angolan Girabola
# event                         : Grupo Desportivo Interclube v Academica Petroleos
# Grupo Desportivo Interclube Home-Win : 6/4
# draw                 Draw     : EVS
# Academica Petroleos do Lobito Away-Win : 15/4
#
#   58 : -SOCCER :  Competition : Sudanese Premier League
# event                         : Alamal Atbara v Hilal El-Fasher
# Alamal Atbara        Home-Win : 4/9
# draw                 Draw     : 14/5
# Hilal El-Fasher      Away-Win : 6/1
#
#   59 : -SOCCER :  Competition : Spanish Segunda Division B - Group 4
# event                         : Cadiz B v San Fernando CD
# Cadiz B              Home-Win : 8/1
# draw                 Draw     : 13/5
# San Fernando CD      Away-Win : 2/5
#
#   60 : -SOCCER :  Competition : Nigerian Premier League
# event                         : Kwara United v Ifeanyi Ubah FC
# Kwara United         Home-Win : EVS
# draw                 Draw     : 5/4
# Ifeanyi Ubah FC      Away-Win : 11/2
#
#   61 : -SOCCER :  Competition : Nigerian Premier League
# event                         : Abia Warriors v MFM FC
# Abia Warriors        Home-Win : 19/20
# draw                 Draw     : 31/20
# MFM FC               Away-Win : 4/1
#
#   62 : -SOCCER :  Competition : Nigerian Premier League
# event                         : Heartland v Akwa United FC
# Heartland            Home-Win : 6/5
# draw                 Draw     : 7/5
# Akwa United FC       Away-Win : 10/3
#
#   63 : -SOCCER :  Competition : Spanish Segunda Division B - Group 3
# event                         : Atletico Levante UD v Villarreal B
# Atletico Levante UD  Home-Win : 13/5
# draw                 Draw     : 11/8
# Villarreal B         Away-Win : 6/4
#
#   64 : -SOCCER :  Competition : Portuguese Campeonato Nacional
# event                         : Sao Joao Ver v Lusitano Vildemoinhos
# Sao Joao Ver         Home-Win : 4/6
# draw                 Draw     : 2/1
# Lusitano Vildemoinhos Away-Win : 5/1
#
#   65 : -SOCCER :  Competition : Portuguese Campeonato Nacional
# event                         : FC Tirsense v Pevidem SC
# FC Tirsense          Home-Win : 9/4
# draw                 Draw     : 7/5
# Pevidem SC           Away-Win : 13/8
#
#   66 : -SOCCER :  Competition : Portuguese Campeonato Nacional
# event                         : Merelinense v Cerveira
# Merelinense          Home-Win : 2/5
# draw                 Draw     : 13/5
# Cerveira             Away-Win : 8/1
#
#   67 : -SOCCER :  Competition : Portuguese Campeonato Nacional
# event                         : Olhanense v Amora
# Olhanense            Home-Win : 19/20
# draw                 Draw     : 17/10
# Amora                Away-Win : 15/4
#
#   68 : -SOCCER :  Competition : Portuguese Campeonato Nacional
# event                         : AD Fafe v Sao Martinho
# AD Fafe              Home-Win : 5/4
# draw                 Draw     : 6/4
# Sao Martinho         Away-Win : 3/1
#
#   69 : -SOCCER :  Competition : Portuguese Campeonato Nacional
# event                         : Real SC v Rabo De Peixe
# Real SC              Home-Win : 15/8
# draw                 Draw     : 2/1
# Rabo de Peixe        Away-Win : 7/5
#
#   70 : -SOCCER :  Competition : Portuguese Campeonato Nacional
# event                         : Praiense SC v Sporting Lisbon B
# Praiense SC          Home-Win : 11/4
# draw                 Draw     : 7/5
# Sporting Lisbon B    Away-Win : 29/20
#
#   71 : -SOCCER :  Competition : Portuguese Campeonato Nacional
# event                         : Guimaraes B v Brito Sc
# Guimaraes B          Home-Win : 31/20
# draw                 Draw     : 21/10
# Brito Sc             Away-Win : 13/8
#
#   72 : -SOCCER :  Competition : Portuguese Campeonato Nacional
# event                         : Alcains v Oleiros
# Alcains              Home-Win : 9/2
# draw                 Draw     : 2/1
# Oleiros              Away-Win : 8/11
#
#   73 : -SOCCER :  Competition : Portuguese Campeonato Nacional
# event                         : Alverca v Loures
# Alverca              Home-Win : 4/9
# draw                 Draw     : 5/2
# Loures               Away-Win : 15/2
#
#   74 : -SOCCER :  Competition : Portuguese Campeonato Nacional
# event                         : Castro Daire v CF Canelas 2010
# Castro Daire         Home-Win : 17/5
# draw                 Draw     : 6/4
# CF Canelas 2010      Away-Win : 11/10
#
#   75 : -SOCCER :  Competition : Portuguese Women's Matches
# event                         : UR Cadima (W) v Fiaes FC (W)
# UR Cadima (W)        Home-Win : 4/5
# draw                 Draw     : 11/5
# Fiaes FC (W)         Away-Win : 7/2
#
#   76 : -SOCCER :  Competition : Portuguese Women's Matches
# event                         : GDC A Dos Francos (W) v Clube Atletico Ouriense (W
# GDC A Dos Francos (W) Home-Win : 9/2
# draw                 Draw     : 27/10
# Clube Atletico Ouriense (W Away-Win : 11/20
#
#   77 : -SOCCER :  Competition : Portuguese Women's Matches
# event                         : Famalicao (W) v Maritimo (W)
# Famalicao (W)        Home-Win : 4/5
# draw                 Draw     : 12/5
# Maritimo (W)         Away-Win : 16/5
#
#   78 : -SOCCER :  Competition : Portuguese Women's Matches
# event                         : Damaiense (W) v Estoril Praia (W)
# Damaiense (W)        Home-Win : 6/1
# draw                 Draw     : 3/1
# Estoril Praia (W)    Away-Win : 2/5
#
#   79 : -SOCCER :  Competition : Spanish Segunda Division B - Group 1
# event                         : Union de Salamanca v Pontevedra CF
# Union de Salamanca   Home-Win : 15/8
# draw                 Draw     : 5/4
# Pontevedra CF        Away-Win : 23/10
#
#   80 : -SOCCER :  Competition : Ghanain Premier League
# event                         : Techiman Eleven Wonders v King Faisal
# Techiman Eleven Wonders Home-Win : 5/6
# draw                 Draw     : 13/8
# King Faisal          Away-Win : 9/2
#
#   81 : -SOCCER :  Competition : Ghanain Premier League
# event                         : Ebusua Dwarfs v Sogakope Wafa
# Ebusua Dwarfs        Home-Win : 9/2
# draw                 Draw     : 5/2
# Sogakope Wafa        Away-Win : 4/7
#
#   82 : -TENNIS :
#   83 : -TENNIS :
#   84 : -TENNIS :
#   85 : -BASKETBALL :
#   86 : -BASKETBALL :
#   87 : -BASKETBALL :
#   88 : -BASKETBALL :
#   89 : -BASKETBALL :
#   90 : -BASKETBALL :
#   91 : -BASKETBALL :
#   92 : -BASKETBALL :
#   93 : -BASKETBALL :
#   94 : -BASKETBALL :
#   95 : -BASKETBALL :
#   96 : -BASKETBALL :
#   97 : -BASKETBALL :
#   98 : -BASKETBALL :
#   99 : -BASKETBALL :
#  100 : -BASKETBALL :
#  101 : -BASKETBALL :
#  102 : -BASKETBALL :
#  103 : -BASKETBALL :
#  104 : -BASKETBALL :
#  105 : -BASKETBALL :
#  106 : -BASKETBALL :
#  107 : -BASKETBALL :
#  108 : -BASKETBALL :
#  109 : -BASKETBALL :
#  110 : -BASKETBALL :
#  111 : -BASKETBALL :
#  112 : -BASKETBALL :
#  113 : -BASKETBALL :
#  114 : -BASKETBALL :
#  115 : -BASKETBALL :
#  116 : -BASKETBALL :
#  117 : -BASKETBALL :
#  118 : -BASKETBALL :
#  119 : -ICE_HOCKEY :
#  120 : -ICE_HOCKEY :
#  121 : -ICE_HOCKEY :
#  122 : -ICE_HOCKEY :
#  123 : -ICE_HOCKEY :
#  124 : -ICE_HOCKEY :
#  125 : -ICE_HOCKEY :
#  126 : -ICE_HOCKEY :
#  127 : -ICE_HOCKEY :
#  128 : -ICE_HOCKEY :
#  129 : -ICE_HOCKEY :
#  130 : -ICE_HOCKEY :
#  131 : -ICE_HOCKEY :
#  132 : -ICE_HOCKEY :
#  133 : -ICE_HOCKEY :
#  134 : -ICE_HOCKEY :
#  135 : -ICE_HOCKEY :
#  136 : -ICE_HOCKEY :
#  137 : -VOLLEYBALL :
#  138 : -VOLLEYBALL :
#  139 : -VOLLEYBALL :
#  140 : -VOLLEYBALL :
#  141 : -VOLLEYBALL :
#  142 : -VOLLEYBALL :
#  143 : -VOLLEYBALL :
#  144 : -VOLLEYBALL :
#  145 : -VOLLEYBALL :
#  146 : -VOLLEYBALL :
#  147 : -VOLLEYBALL :
#  148 : -VOLLEYBALL :
#  149 : -VOLLEYBALL :
#  150 : -VOLLEYBALL :
#  151 : -VOLLEYBALL :
#  152 : -VOLLEYBALL :
#  153 : -VOLLEYBALL :
#  154 : -SNOOKER :
#  155 : -RUGBY_UNION :
#  156 : -RUGBY_UNION :
#  157 : -HANDBALL :
#  158 : -HANDBALL :
#  159 : -HANDBALL :
#  160 : -HANDBALL :
#  161 : -HANDBALL :
#  162 : -HANDBALL :
#  163 : -HANDBALL :
#  164 : -E_SPORTS :
#  165 : -E_SPORTS :
#  166 : -E_SPORTS :
#  167 : -E_SPORTS :
#  168 : -TABLE_TENNIS :
#  169 : -TABLE_TENNIS :
#  170 : -SOCCER :  Competition : Saudi Professional League
# event                         : Al-Ittihad v Al Nasr FC Riyadh
# Al-Ittihad           Home-Win : 7/4
# draw                 Draw     : 23/10
# Al Nasr FC Riyadh    Away-Win : 31/20
#
#  171 : -SOCCER :  Competition : Dutch Eredivisie
# event                         : Feyenoord v AZ Alkmaar
# Feyenoord            Home-Win : 29/20
# draw                 Draw     : 27/10
# Az Alkmaar           Away-Win : 31/20
#
#  172 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : UE Sants v UE Sant Andreu
# UE Sants             Home-Win : 4/1
# draw                 Draw     : 12/5
# UE Sant Andreu       Away-Win : 8/13
#
#  173 : -SOCCER :  Competition : French Ligue 1
# event                         : Rennes v Lille
# Rennes               Home-Win : 19/10
# draw                 Draw     : 9/5
# Lille                Away-Win : 17/10
#
#  174 : -SOCCER :  Competition : Turkish Super League
# event                         : Besiktas v Goztepe
# Besiktas             Home-Win : 40/85
# draw                 Draw     : 10/3
# Goztepe              Away-Win : 11/2
#
#  175 : -SOCCER :  Competition : Turkish Super League
# event                         : Gaziantep FK v Hatayspor
# Gaziantep FK         Home-Win : 11/8
# draw                 Draw     : 23/10
# Hatayspor            Away-Win : 9/5
#
#  176 : -SOCCER :  Competition : Austrian Bundesliga
# event                         : LASK Linz v WSG Wattens
# LASK Linz            Home-Win : 1/3
# draw                 Draw     : 4/1
# WSG Wattens          Away-Win : 13/2
#
#  177 : -SOCCER :  Competition : Scottish League Cup
# event                         : Livingston v St Mirren
# Livingston           Home-Win : 5/4
# draw                 Draw     : 15/8
# St Mirren            Away-Win : 5/2
#
#  178 : -SOCCER :  Competition : Italian Serie C
# event                         : Pontedera v Olbia
# Pontedera            Home-Win : 19/20
# draw                 Draw     : 2/1
# Olbia                Away-Win : 14/5
#
#  179 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : CF Agrupacion Estuduantil v UD Paiosaco
# CF Agrupacion Estuduantil Home-Win : 5/4
# draw                 Draw     : 2/1
# UD Paiosaco          Away-Win : 15/8
#
#  180 : -SOCCER :  Competition : Turkish 1 Lig
# event                         : Samsunspor v Altay
# Samsunspor           Home-Win : 20/23
# draw                 Draw     : 5/2
# Altay                Away-Win : 11/4
#
#  181 : -SOCCER :  Competition : Romanian Liga I
# event                         : Gaz Metan Medias v CSMS Iasi
# Gaz Metan Medias     Home-Win : 21/20
# draw                 Draw     : 19/10
# CSMS Iasi            Away-Win : 3/1
#
#  182 : -SOCCER :  Competition : Spanish Segunda Division B - Group 1
# event                         : Deportivo v SD Compostela
# Deportivo            Home-Win : 1/2
# draw                 Draw     : 13/5
# SD Compostela        Away-Win : 5/1
#
#  183 : -SOCCER :  Competition : Spanish Segunda Division B - Group 5
# event                         : Merida AD v Villanovense
# Merida AD            Home-Win : 6/5
# draw                 Draw     : 9/5
# Villanovense         Away-Win : 9/4
#
#  184 : -SOCCER :  Competition : Spanish Segunda Division B - Group 2
# event                         : Real Union v Leioa
# Real Union           Home-Win : 19/20
# draw                 Draw     : 21/10
# Leioa                Away-Win : 3/1
#
#  185 : -SOCCER :  Competition : Spanish Segunda Division B - Group 2
# event                         : Barakaldo v CD Laredo
# Barakaldo            Home-Win : 13/20
# draw                 Draw     : 23/10
# CD Laredo            Away-Win : 4/1
#
#  186 : -SOCCER :  Competition : Spanish Segunda Division B - Group 2
# event                         : Racing Santander v Athletic Bilbao B
# Racing Santander     Home-Win : 7/5
# draw                 Draw     : 2/1
# Athletic Bilbao B    Away-Win : 21/10
#
#  187 : -SOCCER :  Competition : Spanish Segunda Division B - Group 4
# event                         : Cordoba v Yeclano Deportivo
# Cordoba              Home-Win : 11/20
# draw                 Draw     : 13/5
# Yeclano Deportivo    Away-Win : 11/2
#
#  188 : -SOCCER :  Competition : Spanish Segunda Division B - Group 4
# event                         : Linares Deportivo v UCAM Murcia
# Linares Deportivo    Home-Win : 6/4
# draw                 Draw     : 15/8
# UCAM Murcia          Away-Win : 2/1
#
#  189 : -SOCCER :  Competition : Mexican Women's Matches
# event                         : Mazatlan FC(W) v CF America (W)
# Mazatlan FC(W)       Home-Win : 5/1
# draw                 Draw     : 31/10
# CF America (W)       Away-Win : 2/5
#
#  190 : -SOCCER :  Competition : Croatian 1 HNL
# event                         : NK Istra v Slaven Belupo
# NK Istra             Home-Win : 13/8
# draw                 Draw     : 2/1
# Slaven Belupo        Away-Win : 31/20
#
#  191 : -SOCCER :  Competition : Moroccan Botola 2
# event                         : Olympique Khouribga v Widad Temara
# Olympique Khouribga  Home-Win : 10/11
# draw                 Draw     : 2/1
# Widad Temara         Away-Win : 3/1
#
#  192 : -SOCCER :  Competition : Italian Serie C
# event                         : Cesena v SS Virtus Verona 1921
# Cesena               Home-Win : 3/4
# draw                 Draw     : 12/5
# SS Virtus Verona 1921 Away-Win : 18/5
#
#  193 : -SOCCER :  Competition : Italian Serie C
# event                         : AP Turris Calcio v Calcio Avellino SSD
# AP Turris Calcio     Home-Win : 19/10
# draw                 Draw     : 2/1
# Calcio Avellino SSD  Away-Win : 29/20
#
#  194 : -SOCCER :  Competition : Italian Serie C
# event                         : Bisceglie v Foggia
# Bisceglie            Home-Win : 11/5
# draw                 Draw     : 2/1
# Foggia               Away-Win : 6/5
#
#  195 : -SOCCER :  Competition : Italian Serie C
# event                         : SSD Pro Sesto v Juventus B
# SSD Pro Sesto        Home-Win : 21/10
# draw                 Draw     : 21/10
# Juventus B           Away-Win : 5/4
#
#  196 : -SOCCER :  Competition : Cypriot 1st Division
# event                         : Nea Salamis v Apollon Limassol
# Nea Salamis          Home-Win : 11/2
# draw                 Draw     : 10/3
# Apollon Limassol     Away-Win : 4/9
#
#  197 : -SOCCER :  Competition : English FA Cup
# event                         : Man Utd v Liverpool
# Man Utd              Home-Win : 7/5
# draw                 Draw     : 13/5
# Liverpool            Away-Win : 15/8
#
#  198 : -SOCCER :  Competition : Italian Serie A
# event                         : Lazio v Sassuolo
# Lazio                Home-Win : 4/6
# draw                 Draw     : 3/1
# Sassuolo             Away-Win : 4/1
#
#  199 : -SOCCER :  Competition : German Bundesliga
# event                         : Hoffenheim v FC Koln
# Hoffenheim           Home-Win : 3/4
# draw                 Draw     : 11/4
# FC Koln              Away-Win : 7/2
#
#  200 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : UE Vilassar de Mar v Girona B
# UE Vilassar de Mar   Home-Win : 5/4
# draw                 Draw     : 12/5
# Girona B             Away-Win : 17/10
#
#  201 : -SOCCER :  Competition : Hungarian NB I
# event                         : Honved v Zalaegerszeg
# Honved               Home-Win : 11/10
# draw                 Draw     : 23/10
# Zalaegerszeg         Away-Win : 23/10
#
#  202 : -SOCCER :  Competition : Maltese Premier League
# event                         : Hamrun Spartans FC v Santa Lucia FC
# Hamrun Spartans FC   Home-Win : 2/5
# draw                 Draw     : 7/2
# Santa Lucia FC       Away-Win : 11/2
#
#  203 : -SOCCER :  Competition : Maltese 1st Division
# event                         : San Gwann v Vittoriosa Stars
# San Gwann            Home-Win : 6/5
# draw                 Draw     : 12/5
# Vittoriosa Stars     Away-Win : 9/5
#
#  204 : -SOCCER :  Competition : Andorran Segona Divisio
# event                         : UE Santa Coloma B v FC Encamp
# UE Santa Coloma B    Home-Win : 27/10
# draw                 Draw     : 17/5
# FC Encamp            Away-Win : 8/13
#
#  205 : -SOCCER :  Competition : Israeli Premier League
# event                         : Bnei Yehuda v Hapoel K Saba
# Bnei Yehuda          Home-Win : 6/5
# draw                 Draw     : 2/1
# Hapoel K Saba        Away-Win : 11/5
#
#  206 : -SOCCER :  Competition : US United Premier Football League
# event                         : Houston FC v Round Rock SC
# Houston FC           Home-Win : 5/6
# draw                 Draw     : 29/10
# Round Rock SC        Away-Win : 9/4
#
#  207 : -SOCCER :  Competition : Saudi Professional League
# event                         : Al-Ettifaq v Al Ahli
# Al-Ettifaq           Home-Win : 13/10
# draw                 Draw     : 12/5
# Al Ahli              Away-Win : 19/10
#
#  208 : -SOCCER :  Competition : Spanish Segunda Division
# event                         : CD Castellon v Sporting Gijon
# CD Castellon         Home-Win : 12/5
# draw                 Draw     : 13/8
# Sporting Gijon       Away-Win : 13/10
#
#  209 : -SOCCER :  Competition : Belgian First Division A
# event                         : Standard v Charleroi
# Standard             Home-Win : 10/11
# draw                 Draw     : 12/5
# Charleroi            Away-Win : 14/5
#
#  210 : -SOCCER :  Competition : Spanish La Liga
# event                         : Celta Vigo v Eibar
# Celta Vigo           Home-Win : EVS
# draw                 Draw     : 9/4
# Eibar                Away-Win : 3/1
#
#  211 : -SOCCER :  Competition : Czech 1 Liga
# event                         : Sparta Prague v Mlada Boleslav
# Sparta Prague        Home-Win : 1/3
# draw                 Draw     : 4/1
# Mlada Boleslav       Away-Win : 13/2
#
#  212 : -SOCCER :  Competition : Greek Super League
# event                         : PAOK v AEK Athens
# PAOK                 Home-Win : 3/4
# draw                 Draw     : 12/5
# AEK Athens           Away-Win : 18/5
#
#  213 : -SOCCER :  Competition : Portuguese Primeira Liga
# event                         : Moreirense v Portimonense
# Moreirense           Home-Win : 15/8
# draw                 Draw     : 2/1
# Portimonense         Away-Win : 17/10
#
#  214 : -SOCCER :  Competition : Spanish Segunda Division B - Group 3
# event                         : Barcelona B v Olot
# Barcelona B          Home-Win : 19/20
# draw                 Draw     : 2/1
# Olot                 Away-Win : 10/3
#
#  215 : -SOCCER :  Competition : Sudanese Premier League
# event                         : Al-Hilal Port Sudan v Al Shorta
# Al-Hilal Port Sudan  Home-Win : 2/5
# draw                 Draw     : 10/3
# Al Shorta            Away-Win : 9/2
#
#  216 : -SOCCER :  Competition : Spanish Tercera Division
# event                         : AD Union Adarve v FC Villanueva del Pardillo
# AD Union Adarve      Home-Win : 2/11
# draw                 Draw     : 9/2
# FC Villanueva del Pardillo Away-Win : 11/1
#
#  217 : -SOCCER :  Competition : Romanian Liga I
# event                         : Botosani v Dinamo Bucharest
# Botosani             Home-Win : EVS
# draw                 Draw     : 11/5
# Dinamo Bucharest     Away-Win : 29/10
#
#  218 : -SOCCER :  Competition : Maltese 1st Division
# event                         : Qormi FC v Pieta Hotspurs FC
# Qormi FC             Home-Win : 11/2
# draw                 Draw     : 7/2
# Pieta Hotspurs FC    Away-Win : 1/3
#
#  219 : -SOCCER :  Competition : Ghanain Premier League
# event                         : Asante Kotoko v Aduana Stars
# Asante Kotoko        Home-Win : 17/20
# draw                 Draw     : 9/5
# Aduana Stars         Away-Win : 15/4

# %%
len(LIs)
# Out:
# 179

# %%
LIs[101]
# Out:
# <li class="com-coupon-line avb-row market-1x2 large">
# <div class="event-information ui-inplay ui-has-score ui-event ui-30246486" data-eventid="30246486">
# <div class="details-market market-0-runners">
# <div class="ui-market-handicap-values">
# </div>
# <a class="ui-nav markets-number-arrow ui-top event-link ui-gtm-click" data-competition="Ghanain Premier League" data-dimension3="inplay - coupon line" data-dimension34="/sport/football/ghanain-premier-league/ebusua-dwarfs-v-sogakope-wafa/30246486" data-event="Ebusua Dwarfs v Sogakope Wafa" data-gaaction="navigated to" data-gacategory="navigation" data-galabel="Ebusua Dwarfs v Sogakope Wafa scroller" data-loader="#zone-container .scroller &gt; div" data-market="Match Odds" data-sport="SOCCER" data-sport-id="1" href="/sport/football/ghanain-premier-league/ebusua-dwarfs-v-sogakope-wafa/30246486">
# <span class="icon" title="All Markets"></span>
# </a>
# <div class="runner-list ui-market ui-924_251086724 market-1x2 ui-market-open" data-marketid="924.251086724">
# <ul class="runner-list-selections">
# <li class="selection sel-0">
# <a class="com-bet-button ui-bet-button ui-market-action bet-button-097e4f66fe817efaaf3c5d65fe95a43f346a2183 ui-runner ui-924_251086724-10865438 ui-runner-active ui-betslip-action" data-betslip-action="add-bet" data-context="real" data-eventid="30246486" data-is-fctc="0" data-loader=".multiples-bet-list" data-marketid="924.251086724" data-selectionid="10865438" data-uuid="097e4f66fe817efaaf3c5d65fe95a43f346a2183" href="/sport/inplay?gaMod=inplaysports&amp;eventId=30246486&amp;gaZone=Main&amp;bseId=30246486&amp;isSP=false&amp;bsContext=REAL&amp;bssId=10865438&amp;bsmSt=1611500581000&amp;action=addSelection&amp;bsUUID=097e4f66fe817efaaf3c5d65fe95a43f346a2183&amp;bsmId=924.251086724&amp;modules=betslip&amp;xsrftoken=aced66d1-5e56-11eb-8dfd-fa163e71acc6&amp;bsGroup=30246486" rel="nofollow">
# <span class="ui-runner-price ui-924_251086724-10865438 ui-display-fraction-price">
# 5/4
# </span>
# </a>
# </li>
# <li class="selection sel-1">
# <a class="com-bet-button ui-bet-button ui-market-action bet-button-8375f8ccfac659c0d8f66d71994ecacb98cac030 ui-runner ui-924_251086724-58805 ui-runner-active ui-betslip-action" data-betslip-action="add-bet" data-context="real" data-eventid="30246486" data-is-fctc="0" data-loader=".multiples-bet-list" data-marketid="924.251086724" data-selectionid="58805" data-uuid="8375f8ccfac659c0d8f66d71994ecacb98cac030" href="/sport/inplay?gaMod=inplaysports&amp;eventId=30246486&amp;gaZone=Main&amp;bseId=30246486&amp;isSP=false&amp;bsContext=REAL&amp;bssId=58805&amp;bsmSt=1611500581000&amp;action=addSelection&amp;bsUUID=8375f8ccfac659c0d8f66d71994ecacb98cac030&amp;bsmId=924.251086724&amp;modules=betslip&amp;xsrftoken=aced66d1-5e56-11eb-8dfd-fa163e71acc6&amp;bsGroup=30246486" rel="nofollow">
# <span class="ui-runner-price ui-924_251086724-58805 ui-display-fraction-price">
# 7/4
# </span>
# </a>
# </li>
# <li class="selection sel-2">
# <a class="com-bet-button ui-bet-button ui-market-action bet-button-241a54de46120c2de39754c426a7c4370969679c ui-runner ui-924_251086724-17834390 ui-runner-active ui-betslip-action" data-betslip-action="add-bet" data-context="real" data-eventid="30246486" data-is-fctc="0" data-loader=".multiples-bet-list" data-marketid="924.251086724" data-selectionid="17834390" data-uuid="241a54de46120c2de39754c426a7c4370969679c" href="/sport/inplay?gaMod=inplaysports&amp;eventId=30246486&amp;gaZone=Main&amp;bseId=30246486&amp;isSP=false&amp;bsContext=REAL&amp;bssId=17834390&amp;bsmSt=1611500581000&amp;action=addSelection&amp;bsUUID=241a54de46120c2de39754c426a7c4370969679c&amp;bsmId=924.251086724&amp;modules=betslip&amp;xsrftoken=aced66d1-5e56-11eb-8dfd-fa163e71acc6&amp;bsGroup=30246486" rel="nofollow">
# <span class="ui-runner-price ui-924_251086724-17834390 ui-display-fraction-price">
# 12/5
# </span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="details-event">
# <div class="event-icons">
# <span class="event-icon">
# </span>
# </div>
# <div class="event-name-info ui-market ui-924_251086724 ui-inplay ui-no-status-message" data-marketid="924.251086724">
# <a class="ui-nav event-team-container ui-top event-link ui-gtm-click" data-competition="Ghanain Premier League" data-dimension3="inplay - coupon line" data-dimension34="/sport/football/ghanain-premier-league/ebusua-dwarfs-v-sogakope-wafa/30246486" data-event="Ebusua Dwarfs v Sogakope Wafa" data-gaaction="navigated to" data-gacategory="navigation" data-galabel="Ebusua Dwarfs v Sogakope Wafa" data-loader="#zone-container .scroller &gt; div" data-market="Match Odds" data-sport="SOCCER" data-sport-id="1" href="/sport/football/ghanain-premier-league/ebusua-dwarfs-v-sogakope-wafa/30246486">
# <span class="inplay-indicator going-inplay-icon" title="Will Go In-Play">Will Go In-Play</span>
# <span class="inplay-indicator is-inplay-icon" title="In-Play">In-Play</span>
# <span class="home-team-name" title="Ebusua Dwarfs">
# Ebusua Dwarfs
# </span>
# <span class="ui-score-container inplaynow-score score-template-default">
# <span class="ui-score-home">
# 0
# </span>
# <span class="separator">-</span> <span class="ui-score-away">
# 0
# </span> </span>
# <span class="away-team-name" title="Sogakope Wafa">
# Sogakope Wafa
# </span>
# <span class="et-anim-container">
# <span class="extra-time hidden">ET</span>
# <span class="ui-score-container">
# <span class="event-inplay-state inplay ui-time-stop-format" title="9′">
# 9′
# </span> </span> </span>
# </a>
# </div>
# </div>
# </div>
# </li>

# %%
data
# Out:
# '<li class="com-coupon-line avb-row market-1x2 large"><div class="event-information ui-inplay ui-has-score ui-event ui-30226663" data-eventid="30226663"><div class="details-market market-0-runners"><div class="ui-market-handicap-values"></div><a class="ui-nav markets-number-arrow ui-top event-link ui-gtm-click" data-competition="Spanish La Liga" data-dimension3="inplay - coupon line" data-dimension34="/sport/football/spanish-la-liga/osasuna-v-granada/30226663" data-event="Osasuna v Granada" data-gaaction="navigated to" data-gacategory="navigation" data-galabel="Osasuna v Granada scroller" data-loader="#zone-container .scroller &gt; div" data-market="Match Odds" data-sport="SOCCER" data-sport-id="1" href="/sport/football/spanish-la-liga/osasuna-v-granada/30226663"><span class="icon" title="All Markets"></span></a><div class="runner-list ui-market ui-924_250015649 market-1x2 ui-market-open" data-marketid="924.250015649"><ul class="runner-list-selections"><li class="selection sel-0"><a class="com-bet-button ui-bet-button ui-market-action bet-button-6c1858081cf3f624cbcb97c614b71d5e6bf421c5 ui-runner ui-924_250015649-10543 ui-runner-active ui-betslip-action" data-betslip-action="add-bet" data-context="real" data-eventid="30226663" data-is-fctc="0" data-loader=".multiples-bet-list" data-marketid="924.250015649" data-selectionid="10543" data-uuid="6c1858081cf3f624cbcb97c614b71d5e6bf421c5" href="/sport/inplay?gaMod=inplaysports&amp;eventId=30226663&amp;gaZone=Main&amp;bseId=30226663&amp;isSP=false&amp;bsContext=REAL&amp;bssId=10543&amp;bsmSt=1611493286000&amp;action=addSelection&amp;bsUUID=6c1858081cf3f624cbcb97c614b71d5e6bf421c5&amp;bsmId=924.250015649&amp;modules=betslip&amp;xsrftoken=31197a40-5e50-11eb-ab82-fa163ed56e9d&amp;bsGroup=30226663" rel="nofollow"><span class="ui-runner-price ui-924_250015649-10543 ui-display-fraction-price">1/4</span></a></li><li class="selection sel-1"><a class="com-bet-button ui-bet-button ui-market-action bet-button-1d81cd1c0eb0abd5b2763ffb775be9d701aa0677 ui-runner ui-924_250015649-58805 ui-runner-active ui-betslip-action" data-betslip-action="add-bet" data-context="real" data-eventid="30226663" data-is-fctc="0" data-loader=".multiples-bet-list" data-marketid="924.250015649" data-selectionid="58805" data-uuid="1d81cd1c0eb0abd5b2763ffb775be9d701aa0677" href="/sport/inplay?gaMod=inplaysports&amp;eventId=30226663&amp;gaZone=Main&amp;bseId=30226663&amp;isSP=false&amp;bsContext=REAL&amp;bssId=58805&amp;bsmSt=1611493286000&amp;action=addSelection&amp;bsUUID=1d81cd1c0eb0abd5b2763ffb775be9d701aa0677&amp;bsmId=924.250015649&amp;modules=betslip&amp;xsrftoken=31197a40-5e50-11eb-ab82-fa163ed56e9d&amp;bsGroup=30226663" rel="nofollow"><span class="ui-runner-price ui-924_250015649-58805 ui-display-fraction-price">17/5</span></a></li><li class="selection sel-2"><a class="com-bet-button ui-bet-button ui-market-action bet-button-49be9b56c49adc32bca4b66ec260915d26701a6e ui-runner ui-924_250015649-2255452 ui-runner-active ui-betslip-action" data-betslip-action="add-bet" data-context="real" data-eventid="30226663" data-is-fctc="0" data-loader=".multiples-bet-list" data-marketid="924.250015649" data-selectionid="2255452" data-uuid="49be9b56c49adc32bca4b66ec260915d26701a6e" href="/sport/inplay?gaMod=inplaysports&amp;eventId=30226663&amp;gaZone=Main&amp;bseId=30226663&amp;isSP=false&amp;bsContext=REAL&amp;bssId=2255452&amp;bsmSt=1611493286000&amp;action=addSelection&amp;bsUUID=49be9b56c49adc32bca4b66ec260915d26701a6e&amp;bsmId=924.250015649&amp;modules=betslip&amp;xsrftoken=31197a40-5e50-11eb-ab82-fa163ed56e9d&amp;bsGroup=30226663" rel="nofollow"><span class="ui-runner-price ui-924_250015649-2255452 ui-display-fraction-price">17/1</span></a></li></ul></div></div><div class="details-event"><div class="event-icons"><span class="event-icon"><span class="live-video" title="Watch live now"><span class="icon">Live</span></span></span></div><div class="event-name-info ui-market ui-924_250015649 ui-inplay ui-no-status-message" data- ...
