# %%
import pandas as pd
import os
downloads = '{}\\{}'.format(os.path.expanduser('~'),'Downloads')


df1 = pd.read_excel('{}\\{}'.format(downloads, 'GDC disposal list.xlsx', sheet_name="Sheet1"))
df2 = pd.read_excel('{}\\{}'.format(downloads, 'GDC disks onsite now.xlsx', sheet_name="November 2020"))
disposed = df1[['Data Storage Device ETM Barcode', 'Data Storage Device S/N']]
onsite = df2[['ETM TAGS (HDD)', 'HDD\nS/N']]
# Out:
# C:\Users\carll\Downloads

# %%
onsite.loc[onsite['HDD\nS/N'] == 'PLVB4MHE']
# Out:
#   ETM TAGS (HDD)  HDD\nS/N
# 3    ETMU 008116  PLVB4MHE

# %%
onsite.apply(lambda x: print("nope") if onsite.loc[onsite['HDD\nS/N'] == x[1]].empty else print(x[1]), axis=1)
# Out:
# D0A1PB30H67A
# PEX2WB1E
# PLVB4ZYE
# PLVB4MHE
# 6TB0GKQX
# 6TB0H57C
# PEW89VRE
# PEW80SME
# 3SD38GP5
# 3SD38FPD
# PMVRW4SB
# PMVT05ZB
# 6XM4VPM4
# 3NM6A41A
# 3NM6APPR
# D301PC30NHW3
# D301PC30NHLD
# D301PC30N67N
# S0K0T1P5
# S0K0S83C
# 53J0A0CEFRP9
# PLYN0VDE
# S0K0TF53
# S0K0SVPL
# PLYLWKEE
# PLYJN9BE
# 6SR056Y9
# 3SR06YD5
# 3SR0CBT4
# 6SR01XQ7
# 6SR01X4V
# 6SR01TQF
# 3SR0H31Q
# 3SJ1MLNG
# 6SR05GF5
# 6SR059WZ
# 3SR0EGC0
# 6SR08E7T
# 6SR08B1Q
# 6SR06FNR
# 3SR088KW
# 6SR073CD
# 3SR0GWVC
# 3SR08327
# J0XEPT5S
# 6SR01CKA
# 6SR01ANJ
# 6SR08DD1
# 3SR0DXDW
# 6SR08CBF
# 6SR05XY4
# 68M0A066FDSD
# 6SR07NCV
# 3SR08BJ4
# 3SR0A4AS
# 3SR0EVZC
# 3SR0GNT6
# CVX7KD1N
# CVWVTW0N
# 3SR0BFX6
# 6SR02MXP
# 6SR08J7J
# 6SR085YB
# 6SR03SJ4
# 6SR05KNC
# 6SR01N24
# 6SR05K2H
# 3SR09M1K
# 3SR009BZ
# 6SR07N1Z
# 6SR07JG8
# 6SR086NQ
# 3SR09M8W
# 3SR0FQ76
# 6SR01LDW
# 6SR050K7
# 3SR0BEAB
# 6SR071EZ
# 6SR03DLD
# 6SR084VD
# 3SR0B5JD
# 3SR042RB
# 3SR0DW8S
# 6SR085SV
# 6SR02P76
# 6SR0864R
# 6SR038L9
# 3SR0CHQY
# ...

# %%
pd.options.display.max_rows = 999
onsite.apply(lambda x: print("nope") if disposed.loc[disposed['Data Storage Device S/N'] == x[1]].empty else print(x[1]), axis=1)
# Out:
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ...

# %%
onsite.apply(lambda x: print("nope") if disposed.loc[disposed['Data Storage Device ETM Barcode'] == x[0]].empty else print(x[0]), axis=1)
# Out:
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ...
